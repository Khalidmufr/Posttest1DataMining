# %% [markdown]
# <a href="https://colab.research.google.com/github/Khalidmufr/Posttest1DataMining/blob/main/C_2109116100_Posttest_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Khalid Mu'afi Rabbani**
#
# ---
#
# **2109116100**

# %% [markdown]
# # (1) Apriori

# %% [markdown]
# Gunakan dataset ini : https://drive.google.com/file/d/1BqC-2d1ZYqFIFwdjdsW5bAAqNFh2AO4C/view?usp=share_link
#
# Dan buatlah daftar support dan confidence untuk 2 item set dengan menggunakan dataset tersebut (hint : buatlah tabel tabulasi terlebih dahulu untuk
# memudahkan)

# %% [markdown]
# **Tabel Tabulasi**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import itertools

# %%
my_list = ["whole milk", "pastry", "salty snack", "sausage", "semi-finished bread", "yogurt", "soda", 
           "pickled vegetables", "canned beer", "misc. beverages", "hygiene articles", "rolls/buns", 
           "whipped/sour cream", "curd", "beef", "white bread", "butter", "frozen vegetables", "other vegetables", 
           "tropical fruit", "sugar", "buttermilk", "specialty chocolate", "frozen meals", "dental care", 
           "root vegetables", "detergent", "dish cleaner", "cling film/bags"]

combinations = itertools.combinations(my_list, 2)

# %%
# untuk melihat kombinasi 2 item set dari data yang telah diberikan
# menghitung berapa banyak kombinasi 2 item set

count = 0
for comb in combinations:
    count += 1
    print(comb)


print("Jumlah kombinasi:", count)

# %% [markdown]
# *Support*

# %%
# kode dibawah ini untuk mencari nilai support dari setiap kombinasi 2 item

transactions = [
    ["whole milk", "pastry", "salty snack"],
    ["sausage", "whole milk", "semi-finished bread", "yogurt"],
    ["soda", "pickled vegetables"],
    ["canned beer", "misc. beverages"],
    ["sausage", "hygiene articles"],
    ["sausage", "whole milk", "rolls/buns"],
    ["whole milk", "soda"],
    ["frankfurter", "soda", "whipped/sour cream"],
    ["frankfurter", "curd"],
    ["beef", "white bread"],
    ["butter", "whole milk"],
    ["frozen vegetables", "other vegetables"],
    ["tropical fruit", "sugar"],
    ["buttermilk", "specialty chocolate"],
    ["frozen meals", "dental care"],
    ["rolls/buns", "rolls/buns"],
    ["root vegetables", "detergent"],
    ["sausage", "rolls/buns"],
    ["dish cleaner", "cling film/bags"]
]

num_transactions = len(transactions)
combinations = itertools.combinations(my_list, 2)

for comb in combinations:
    count = 0
    for transaction in transactions:
        if set(comb).issubset(set(transaction)):
            count += 1
    support = count / num_transactions
    print(comb, ":", support)

# %% [markdown]
# *Confidence*

# %%
from itertools import combinations

# %%
# mencari nilai confidence dari kombinasi 2 set item 

transactions = [
    ['whole milk', 'pastry', 'salty snack'],
    ['sausage', 'whole milk', 'semi-finished bread', 'yogurt'],
    ['soda', 'pickled vegetables'],
    ['canned beer', 'misc. beverages'],
    ['sausage', 'hygiene articles'],
    ['sausage', 'whole milk', 'rolls/buns'],
    ['whole milk', 'soda'],
    ['frankfurter', 'soda', 'whipped/sour cream'],
    ['frankfurter', 'curd'],
    ['beef', 'white bread'],
    ['butter', 'whole milk'],
    ['frozen vegetables', 'other vegetables'],
    ['tropical fruit', 'sugar'],
    ['butter milk', 'specialty chocolate'],
    ['frozen meals', 'dental care'],
    ['rolls/buns', 'rolls/buns'],
    ['root vegetables', 'detergent'],
    ['sausage', 'rolls/buns'],
    ['dish cleaner', 'cling film/bags']
]

unique_items = [
    'whole milk', 'pastry', 'salty snack', 'sausage', 'semi-finished bread',
    'yogurt', 'soda', 'pickled vegetables', 'canned beer', 'misc. beverages',
    'hygiene articles', 'rolls/buns', 'frankfurter', 'whipped/sour cream', 
    'curd', 'beef', 'white bread', 'butter', 'frozen vegetables', 
    'other vegetables', 'tropical fruit', 'sugar', 'butter milk', 
    'specialty chocolate', 'frozen meals', 'dental care', 'root vegetables', 
    'detergent', 'dish cleaner', 'cling film/bags'
]

num_transactions = len(transactions)

for comb in combinations(unique_items, 2):
    count_both = 0
    count_left = 0
    for transaction in transactions:
        if all(item in transaction for item in comb):
            count_both += 1
        if comb[0] in transaction:
            count_left += 1
    confidence = count_both / count_left
    print(comb, ":", confidence)

# %% [markdown]
# #(2) KNN
#
# Gunakan dataset ini : https://drive.google.com/file/d/1pXAJZZXCXosf0PTJkyogopKaPFxCYl22/view?usp=share_link
#
# Kemudian buatlah tabel jarak berdasarkan data berikut ini :
#
# ![Gambar](data:image/png;base64,...)
# <!-- 1412 -->

# %%
# 1. Tambahkan kolom jarak untuk menampilkan jarak dari dataset terhadap target prediksi

# %%
# 2. Urutkan data berdasarkan K jarak terdekat (Untuk K nya ambil akar 2 dari banyak data)

# %%
# 3. Tentukan apa hasil prediksinya berdasarkan label terbanyak

# %%
import pandas as pd

# %%
dfku = pd.read_csv('deteksi_uang_palsu.csv')

# %%
dfku
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    172.06       104.24        103.66        4.24       3.10
# 1        True    171.66       103.68        103.41        4.35       3.33
# 2        True    172.23       104.00        103.35        4.43       2.95
# 3        True    172.07       104.21        103.82        4.29       3.35
# 4        True    171.79       104.57        104.04        4.26       3.15
# 5       False    172.00       104.23        104.52        5.76       3.37
# 6       False    171.56       104.03        103.93        5.47       3.50
# 7       False    171.90       104.33        104.40        4.70       3.31
# 8       False    171.84       104.06        104.10        4.87       3.25
# 9       False    172.11       104.14        104.15        4.84       3.28
#
#    length
# 0  113.02
# 1  113.74
# 2  113.12
# 3  113.30
# 4  113.46
# 5  110.94
# 6  111.67
# 7  112.12
# 8  111.04
# 9  110.98

# %%
# Import library yang dibutuhkan
import pandas as pd
import numpy as np

# Membaca dataset dari file CSV
df = pd.read_csv('deteksi_uang_palsu.csv')

# Memisahkan target variabel dan variabel input
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

# Mengimpor algoritma KNN dari scikit-learn
from sklearn.neighbors import KNeighborsClassifier

# Inisialisasi model KNN dengan k=3
knn = KNeighborsClassifier(n_neighbors=3)

# Melatih model dengan data latih
knn.fit(X, y)

# Meminta inputan dari pengguna
nilaia = float(input("Masukkan Nilai Diagonal : "))
nilaib = float(input("Masukkan Nilai Height Left : "))
nilaic = float(input("Masukkan Nilai Height Right : "))
nilaid = float(input("Masukkan Nilai Margin Low : "))
nilaie = float(input("Masukkan Nilai Margin Up : "))
nilaif = float(input("Masukkan Nilai Length : "))

# Menginputkan 6 nilai untuk diprediksi
input_values = np.array([nilaia,	nilaib,	nilaic,	nilaid,	nilaie,	nilaif]).reshape(1,-1)

# Melakukan prediksi dengan model yang sudah dilatih
prediction = knn.predict(input_values)

# Menampilkan hasil prediksi
print("Hasil prediksi: ", prediction[0])
# Out:
# Masukkan Nilai Diagonal : 123
# Masukkan Nilai Height Left : 43
# Masukkan Nilai Height Right : 23
# Masukkan Nilai Margin Low : 12
# Masukkan Nilai Margin Up : 54
# Masukkan Nilai Length : 32
# Hasil prediksi:  False

# %% [markdown]
# # (3) Analisis

# %% [markdown]
# > Nama : Khalid Mu'afi Rabbani
#
# > Nim : 2109116100

# %% [markdown]
# Penjelasan posttest :
#
# Pilihlah salah satu tema dari daftar tema ini :
# 1. Perbankan
# 2. Kesehatan
# 3. Ritel
# 4. Pendidkan
#
# Kemudian lakukan analisis dengan menggunakan struktur CRISP-DM
#
# Dimulai dari Business Understanding Hingga Data Preparation
# <img src="https://th.bing.com/th/id/R.f8efea41ae3cd96d86fbc5b10f81ad77?rik=K4Dr%2biIaVGvW8g&riu=http%3a%2f%2fwww.dataprix.com%2ffiles%2fCRISPDM%2fMetodologia_CRISP_DM1_html_52cdbecf.png&ehk=6ONLJMCVxE421Sjt2JJPE6MfCzrL7LLhDZQPdkJTLcw%3d&risl=&pid=ImgRaw&r=0"/>
#
# Tentukan judul dengan ketentuan setiap orang di kelas beda-beda judulnya dan sumber datasetnya (contoh bisa prediksi atau aturan asosiasi)
#
# Catatan : Tugas ini akan berhubungan dengan posttest terakhir (pertemuan 6)

# %% [markdown]
# dataset menggunakan data yang telah disediakan oleh kaggle
#
# link untuk dataset : https://www.kaggle.com/datasets/santoshd3/bank-customers

# %% [markdown]
# **Business Understanding**

# %% [markdown]
# *Determine Business Objectives*
#
# > untuk memprediksi pengguna apakah ia akan menarik uang lewat bank atau tidak

# %% [markdown]
# *Assess Situation*
#
# > data yang digunakan adalah data yang disediakan oleh website kaggle

# %% [markdown]
# *Determine Data Mining Goals*
#
# > dapat memprediksi pengguna apakah ia akan menarik uang lewat bank atau tidak dengan presentasi betul tinggi

# %% [markdown]
# *Produce Project Plan*
#
# > menggunakan algoritma knn dengan library python dan pandas

# %% [markdown]
# **Data Understanding**

# %% [markdown]
# *Collect Initial Data*

# %%
import pandas as pd

# %%
df = pd.read_csv("Churn Modeling.csv")

# %% [markdown]
# *Describe Data*

# %%
df.head()   # menampilkan 5 data pertama

# %%
df.describe()   # mendeskripsikan rata-rata, standar deviasi, q1, q2, q3, dan lain-lain dari setiap kolom

# %%
df.info()   # melihat informasi dari setiap kolom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.columns

# %% [markdown]
# *Explore Data*

# %%
import seaborn as sb            
import plotly.express as px

# %%
df

# %%
sb.countplot(data=df, x="IsActiveMember")   # menampilkan grafik dari kolom IsActiveMember yang memiliki 2 nilai

# %%
sb.countplot(data=df[df["Gender"] == "Male"], x="Geography")  # menampilkan grafik geografi tetapi hanya yang memiliki gender male

# %%
sb.histplot(data=df, x="Balance", kde=True)   # menampilkan histogram dari kolom balance

# %%
sb.boxplot(data=df, x="Age")    # menampilkan boxplor dari kolom age

# %%
sb.scatterplot(data=df, x="Age", y="CreditScore")   # menampilkan grafik dari kolom age sebagai nilai x dan kolom credit score sebagai nilai y

# %%
px.pie(df, names="Tenure")    # membuat diagram pie dari kolom tenure

# %%
sb.countplot(data=df, x="Age", hue="Exited")    # menampilkan grafik dari kolom age dan exited

# %% [markdown]
# *Verify Data Quality*

# %%
df.isna().sum()   # mengecek apakah data ada yang kosong dalam barisnya di setiap kolom

# %% [markdown]
# **Data Preparation**

# %% [markdown]
# *Select Data*

# %%
df2 = pd.read_csv("Churn Modeling.csv")   # memilih data yang akan digunakan

# %% [markdown]
# *Clean Data*

# %%
df2.isna().sum()    # mengecek apakah ada baris dari suatu kolom yang kosong
                    # apabila tidak ada maka data telah bersih

# %% [markdown]
# *Construct Data*

# %%
df2
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
del df2["RowNumber"]        # menghapus kolom yang tidak diperlukan
del df2["CustomerId"]
del df2["Surname"]

# %%
df2

# %% [markdown]
# *Integrate Data*
#
# > mengintegrasikan data apabila dari suatu kolom itu diperlukan

# %% [markdown]
# *Format Data*
#
# > memformat data atau bisa juga menggganti nilai dari data kelas menjadi int, atau dapat juga merubah type data dari int64 ke float64
